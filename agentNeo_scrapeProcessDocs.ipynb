# %% [markdown]
# # Scrape URLs and Generate Document Embeddings
#
# This is the **first notebook** in the Agent Neo workflow. At a high level, this notebook scrapes Neo4j and GDS documentation websites, creates smaller document chunks, converts the text chunks into vectors, and saves the documents and vectors to a GCP bucket.
#
# Specifically, this notebook completes the following steps:
# * Parse Neo4j documentation XML sitemaps to gather individual URLs for scraping
# * Combine these URLs with other useful Neo4j and GDS resources that have been manually collected
# * Scrape the combined list of documents using LangChain
# * Sub-divide the scraped pages into smaller document chunks
# * Create embeddings of the document chunks using GCP Text to VertexAI Text Embedding
# * Save the text chunks, embeddings, and reference URLs to a GCP bucket
#
# References:
# * [Generative AI / LLM - Document Retrieval and Question Answering](https://www.youtube.com/watch?v=inAY6M6UUkk)
# * [Using Vertex AI Matching Engine and Vertex AI Embeddings for Text for StackOverflow Questions](https://github.com/GoogleCloudPlatform/vertex-ai-samples/blob/main/notebooks/official/matching_engine/sdk_matching_engine_create_stack_overflow_embeddings_vertex.ipynb)

# %%
# !pip3 install --upgrade google-cloud-aiplatform google-cloud-storage

# %%
# !pip install langchain --upgrade
# !pip install unstructured --upgrade # used by langchain
# !pip install pdf2image --upgrade # used by langchain
# !pip install tensorflow_text --upgrade # used by langchain

# %%
import os
import time
import logging
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

import json

# %%
import langchain
from langchain.document_loaders import UnstructuredURLLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import VertexAIEmbeddings

import requests
from bs4 import BeautifulSoup

import tensorflow_text
from google.cloud import aiplatform
# Out:
# 2023-07-28 18:36:22.971928: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # GCP Authentication and Details

# %% [markdown]
# ## Authenticate Account

# %%
# run the below in the jupyter terminal to authenticate your google account
# ! gcloud auth login

# %% [markdown]
# ## Set Project and Region

# %%
PROJECT_ID = ''
REGION = ""

# %%
! gcloud config set project {PROJECT_ID}
# Out:
# Updated property [core/project].

# %%
aiplatform.init(project=PROJECT_ID, location=REGION)

# %% [markdown]
# # Get Lists of Websites to Scrape

# %% [markdown]
# ## URLs from Neo4j Documentation Sitemaps

# %%
def parse_sitemap(sitemap) -> list:
    '''Parse a top-level sitemap to get a list of URLs
    inputs:
        sitemap: url comtaining an xml site map
        
    returns:
        parsed list of urls on the sitemap
    '''
    response = requests.get(sitemap)
    soup = BeautifulSoup(response.content, "xml")
    urls = [element.text for element in soup.find_all("loc")]
    return urls

# %%
neo4j_sitemaps = [
    'https://neo4j.com/docs/graph-data-science/current/sitemap.xml', # core GDS
    'https://neo4j.com/docs/graph-data-science-client/current/sitemap.xml', # GDS client
    'https://neo4j.com/docs/python-manual/current/sitemap.xml', # Neo4j python client 
    'https://neo4j.com/docs/cypher-manual/current/sitemap.xml', # Cypher manual 
    'https://neo4j.com/docs/apoc/current/sitemap.xml', # APOC manual
    'https://neo4j.com/docs/aura/sitemap.xml', # Aura DB and DS
    'https://neo4j.com/docs/operations-manual/5/sitemap.xml' # Neo4j5
]

# %%
# parse sitemaps into a single list 
neo4j_doc_sites = []
neo4j_doc_sites = [x for sitemap in neo4j_sitemaps for x in parse_sitemap(sitemap)]
len(neo4j_doc_sites)
# Out:
# 1098

# %% [markdown]
# ## Unofficial Practitioner's Guide to GDS
# Markdown pages from the supplemental Neo4j and GDS guides I have created during my work as a GDS CSA.

# %%
practitioners_guide_sites = [
    'https://github.com/danb-neo4j/gds-guide/blob/main/README.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/gds-resources.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/graph-data-modeling.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/graph-eda.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/graphs-llms.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/neo4j-resources.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/usecase-specific.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/algorithms/README.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/algorithms/gds_centrality.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/algorithms/gds_community.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/algorithms/gds_pathfinding.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/algorithms/gds_similarity.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/embeddings/README.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/embeddings/fastrp.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/embeddings/graphSAGE.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/embeddings/hashGNN.md',
    'https://github.com/danb-neo4j/gds-guide/blob/main/embeddings/node2vec.md',
]
len(practitioners_guide_sites)
# Out:
# 17

# %% [markdown]
# ## Other Articles and Resources
# The following is a list of Neo4j Developer Blogs and related GDS content that is recommended for additional Neo4j and GDS context.

# %%
other_articles = [
    'https://neo4j.com/developer-blog/get-started-with-neo4j-gds-python-client/',
    'https://medium.com/neo4j/graph-data-modeling-categorical-variables-dd8a2845d5e0',
    'https://medium.com/neo4j/graph-modeling-labels-71775ff7d121',
    'https://medium.com/neo4j/graph-data-modeling-all-about-relationships-5060e46820ce',
    'https://medium.com/neo4j/graph-data-modeling-keys-a5a5334a1297'
    'https://medium.com/neo4j/modeling-patient-journeys-with-neo4j-d0785fbbf5a2'
    'https://neo4j.com/docs/graph-data-science/current/installation/System-requirements/',
    'https://neo4j.com/developer/kb/understanding-memory-consumption/',
    'https://neo4j.com/developer-blog/exploring-fraud-detection-neo4j-graph-data-science-summary/',
    'https://neo4j.com/developer-blog/exploring-fraud-detection-neo4j-graph-data-science-part-1/',
    'https://neo4j.com/developer-blog/exploring-fraud-detection-neo4j-graph-data-science-part-2/',
    'https://neo4j.com/developer-blog/exploring-fraud-detection-neo4j-graph-data-science-part-3/',
    'https://neo4j.com/developer-blog/exploring-fraud-detection-neo4j-graph-data-science-part-4/',
    'https://medium.com/neo4j/using-neo4j-graph-data-science-in-python-to-improve-machine-learning-models-c55a4e15f530',
    'https://medium.com/neo4j/user-segmentation-based-on-node-roles-in-the-peer-to-peer-payment-network-1a766c60a4ee',
    'https://medium.com/data-science-at-microsoft/using-graphs-to-model-and-analyze-the-customer-journey-4b1f1e9f3696',
    'https://towardsdatascience.com/exploring-practical-recommendation-engines-in-neo4j-ff09fe767782',
    'https://neo4j.com/developer-blog/supply-chain-neo4j-gds-bloom/',
    'https://neo4j.com/developer-blog/gds-supply-chains-metrics-performance-python/',
    'https://neo4j.com/developer-blog/gds-supply-chain-pathfinding-optimization/',
    'https://medium.com/neo4j/knowledge-graphs-llms-real-time-graph-analytics-89b392eaaa95',
    'https://medium.com/neo4j/knowledge-graphs-llms-multi-hop-question-answering-322113f53f51',
    'https://towardsdatascience.com/integrate-llm-workflows-with-knowledge-graph-using-neo4j-and-apoc-27ef7e9900a2',
    'https://medium.com/neo4j/knowledge-graphs-llms-fine-tuning-vs-retrieval-augmented-generation-30e875d63a35',
    'https://medium.com/neo4j/langchain-cypher-search-tips-tricks-f7c9e9abca4d',
    'https://towardsdatascience.com/langchain-has-added-cypher-search-cb9d821120d5',
    'https://medium.com/neo4j/generating-cypher-queries-with-chatgpt-4-on-any-graph-schema-a57d7082a7e7',
    'https://towardsdatascience.com/fine-tuning-an-llm-model-with-h2o-llm-studio-to-generate-cypher-statements-3f34822ad5',
    'https://towardsdatascience.com/implementing-a-sales-support-agent-with-langchain-63c4761193e7',
    'https://towardsdatascience.com/integrating-neo4j-into-the-langchain-ecosystem-df0e988344d2',
    'https://medium.com/neo4j/context-aware-knowledge-graph-chatbot-with-gpt-4-and-neo4j-d3a99e8ae21e',
    'https://towardsdatascience.com/what-happened-with-apoc-in-neo4j-v5-core-and-extended-edition-23994cdf0a2c',
    'https://medium.com/neo4j/creating-a-knowledge-graph-from-video-transcripts-with-gpt-4-52d7c7b9f32c',
    'https://towardsdatascience.com/how-to-use-cypher-aggregations-in-neo4j-graph-data-science-library-5d8c40c2670c',
    'https://medium.com/neo4j/enhancing-word-embedding-with-graph-neural-networks-c26d8e54fe4a',
    'https://medium.com/neo4j/knowledge-graph-based-chatbot-with-gpt-3-and-neo4j-c4ebbd325ed',
    'https://towardsdatascience.com/use-chatgpt-to-query-your-neo4j-database-78680a05ec2',
    'https://towardsdatascience.com/how-cypher-changed-in-neo4j-v5-d0f10cbb60bf',
    'https://towardsdatascience.com/analyze-your-website-with-nlp-and-knowledge-graphs-88e291f6cbf4',
    'https://towardsdatascience.com/investigate-family-connections-between-house-of-dragon-and-game-of-thrones-characters-ff2afd5bdb82',
    'https://medium.com/neo4j/user-segmentation-based-on-node-roles-in-the-peer-to-peer-payment-network-1a766c60a4ee',
    'https://towardsdatascience.com/analyzing-the-evolution-of-life-on-earth-with-neo4j-7daeeb1e032d',
    'https://medium.com/neo4j/how-to-get-started-with-the-neo4j-graph-data-science-python-client-56209d9b0d0d',
    'https://towardsdatascience.com/extract-knowledge-from-text-end-to-end-information-extraction-pipeline-with-spacy-and-neo4j-502b2b1e0754',
    'https://towardsdatascience.com/batching-transactions-in-neo4j-1001d12c9a4a',
    
]

# %% [markdown]
# ## Combine Site Lists

# %%
combined_neo4j_gds_sites = neo4j_doc_sites + practitioners_guide_sites + other_articles
combined_neo4j_gds_sites = list(set(combined_neo4j_gds_sites))

print('total web pages to scrape:', len(combined_neo4j_gds_sites))
# Out:
# total web pages to scrape: 1157

# %% [markdown]
# # Scrape Sites into LangChain Documents

# %%
# instantiate the loader with our combined URL list
loader = UnstructuredURLLoader(urls=combined_neo4j_gds_sites)

# %%
# run the loader and save scraped documents
documents = loader.load()

# %%
# number of documents scraped
print('number of documents scraped:', len(documents))
# Out:
# number of documents scraped: 1157

# %%
# # uncomment to view text from a scraped document 
# documents[999]

# %% [markdown]
# # Chunk Scraped Documents

# %%
# instantiate CharacterTextSplittler to chunk scraped documents
text_splitter = CharacterTextSplitter(
    separator = "\n", # split on newline character
    chunk_size = 512, # smaller for context windows
    chunk_overlap  = 51) # set approx 10% overlap between chunked documents

# %%
# apply splitter to scraped documents
# NOTE: some chunks may be larger than specified chunk_size due to location of separator 
# returns a list of langchain 'Documents'
document_chunks = text_splitter.split_documents(documents)
# Out:
# Created a chunk of size 513, which is longer than the specified 512
# Created a chunk of size 780, which is longer than the specified 512
# Created a chunk of size 513, which is longer than the specified 512
# Created a chunk of size 823, which is longer than the specified 512
# Created a chunk of size 1209, which is longer than the specified 512
# Created a chunk of size 887, which is longer than the specified 512
# Created a chunk of size 662, which is longer than the specified 512
# Created a chunk of size 589, which is longer than the specified 512
# Created a chunk of size 620, which is longer than the specified 512
# Created a chunk of size 534, which is longer than the specified 512
# Created a chunk of size 643, which is longer than the specified 512
# Created a chunk of size 557, which is longer than the specified 512
# Created a chunk of size 556, which is longer than the specified 512
# Created a chunk of size 601, which is longer than the specified 512
# Created a chunk of size 589, which is longer than the specified 512
# Created a chunk of size 522, which is longer than the specified 512
# Created a chunk of size 936, which is longer than the specified 512
# Created a chunk of size 655, which is longer than the specified 512
# Created a chunk of size 667, which is longer than the specified 512
# Created a chunk of size 745, which is longer than the specified 512
# Created a chunk of size 681, which is longer than the specified 512
# Created a chunk of size 928, which is longer than the specified 512
# Created a chunk of size 577, which is longer than the specified 512
# Created a chunk of size 569, which is longer than the specified 512
# Created a chunk of size 572, which is longer than the specified 512
# Created a chunk of size 1328, which is longer than the specified 512
# Created a chunk of size 824, which is longer than the specified 512
# Created a chunk of size 604, which is longer than the specified 512
# Created a chunk of size 608, which is longer than the specified 512
# Created a chunk of size 949, which is longer than the specified 512
# Created a chunk of size 611, which is longer than the specified 512
# Created a chunk of size 577, which is longer than the specified 512
# Created a chunk of size 539, which is longer than the specified 512
# Created a chunk of size 520, which is longer than the specified 512
# Created a chunk of size 633, which is longer than the specified 512
# Created a chunk of size 883, which is longer than the specified 512
# Created a chunk of size 985, which is longer than the specified 512
# Created a chunk of size 694, which is longer than the specified 512
# Created a chunk of size 547, which is longer than the specified 512
# Created a chunk of size 604, which is longer than the specified 512
# Created a chunk of size 578, which is longer than the specified 512
# Created a chunk of size 550, which is longer than the specified 512
# Created a chunk of size 815, which is longer than the specified 512
# Created a chunk of size 4738, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 513, which is longer than the specified 512
# Created a chunk of size 576, which is longer than the specified 512
# Created a chunk of size 900, which is longer than the specified 512
# Created a chunk of size 534, which is longer than the specified 512
# Created a chunk of size 585, which is longer than the specified 512
# Created a chunk of size 675, which is longer than the specified 512
# Created a chunk of size 1341, which is longer than the specified 512
# Created a chunk of size 570, which is longer than the specified 512
# Created a chunk of size 933, which is longer than the specified 512
# Created a chunk of size 594, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 1428, which is longer than the specified 512
# Created a chunk of size 982, which is longer than the specified 512
# Created a chunk of size 592, which is longer than the specified 512
# Created a chunk of size 625, which is longer than the specified 512
# Created a chunk of size 631, which is longer than the specified 512
# Created a chunk of size 581, which is longer than the specified 512
# Created a chunk of size 520, which is longer than the specified 512
# Created a chunk of size 718, which is longer than the specified 512
# Created a chunk of size 647, which is longer than the specified 512
# Created a chunk of size 523, which is longer than the specified 512
# Created a chunk of size 605, which is longer than the specified 512
# Created a chunk of size 677, which is longer than the specified 512
# Created a chunk of size 591, which is longer than the specified 512
# Created a chunk of size 649, which is longer than the specified 512
# Created a chunk of size 599, which is longer than the specified 512
# Created a chunk of size 792, which is longer than the specified 512
# Created a chunk of size 866, which is longer than the specified 512
# Created a chunk of size 623, which is longer than the specified 512
# Created a chunk of size 520, which is longer than the specified 512
# Created a chunk of size 598, which is longer than the specified 512
# Created a chunk of size 584, which is longer than the specified 512
# Created a chunk of size 655, which is longer than the specified 512
# Created a chunk of size 564, which is longer than the specified 512
# Created a chunk of size 651, which is longer than the specified 512
# Created a chunk of size 863, which is longer than the specified 512
# Created a chunk of size 843, which is longer than the specified 512
# Created a chunk of size 539, which is longer than the specified 512
# Created a chunk of size 848, which is longer than the specified 512
# Created a chunk of size 1052, which is longer than the specified 512
# Created a chunk of size 873, which is longer than the specified 512
# Created a chunk of size 900, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 1073, which is longer than the specified 512
# Created a chunk of size 712, which is longer than the specified 512
# Created a chunk of size 749, which is longer than the specified 512
# Created a chunk of size 525, which is longer than the specified 512
# Created a chunk of size 563, which is longer than the specified 512
# Created a chunk of size 563, which is longer than the specified 512
# Created a chunk of size 811, which is longer than the specified 512
# Created a chunk of size 582, which is longer than the specified 512
# Created a chunk of size 608, which is longer than the specified 512
# Created a chunk of size 561, which is longer than the specified 512
# Created a chunk of size 571, which is longer than the specified 512
# Created a chunk of size 679, which is longer than the specified 512
# Created a chunk of size 734, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 521, which is longer than the specified 512
# Created a chunk of size 663, which is longer than the specified 512
# Created a chunk of size 551, which is longer than the specified 512
# Created a chunk of size 665, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 641, which is longer than the specified 512
# Created a chunk of size 572, which is longer than the specified 512
# Created a chunk of size 606, which is longer than the specified 512
# Created a chunk of size 716, which is longer than the specified 512
# Created a chunk of size 1198, which is longer than the specified 512
# Created a chunk of size 966, which is longer than the specified 512
# Created a chunk of size 642, which is longer than the specified 512
# Created a chunk of size 743, which is longer than the specified 512
# Created a chunk of size 589, which is longer than the specified 512
# Created a chunk of size 588, which is longer than the specified 512
# Created a chunk of size 1041, which is longer than the specified 512
# Created a chunk of size 664, which is longer than the specified 512
# Created a chunk of size 525, which is longer than the specified 512
# Created a chunk of size 518, which is longer than the specified 512
# Created a chunk of size 523, which is longer than the specified 512
# Created a chunk of size 519, which is longer than the specified 512
# Created a chunk of size 1208, which is longer than the specified 512
# Created a chunk of size 795, which is longer than the specified 512
# Created a chunk of size 756, which is longer than the specified 512
# Created a chunk of size 733, which is longer than the specified 512
# Created a chunk of size 561, which is longer than the specified 512
# Created a chunk of size 589, which is longer than the specified 512
# Created a chunk of size 589, which is longer than the specified 512
# Created a chunk of size 712, which is longer than the specified 512
# Created a chunk of size 677, which is longer than the specified 512
# Created a chunk of size 654, which is longer than the specified 512
# Created a chunk of size 522, which is longer than the specified 512
# Created a chunk of size 541, which is longer than the specified 512
# Created a chunk of size 559, which is longer than the specified 512
# Created a chunk of size 604, which is longer than the specified 512
# Created a chunk of size 1350, which is longer than the specified 512
# Created a chunk of size 565, which is longer than the specified 512
# Created a chunk of size 645, which is longer than the specified 512
# Created a chunk of size 673, which is longer than the specified 512
# Created a chunk of size 690, which is longer than the specified 512
# Created a chunk of size 663, which is longer than the specified 512
# Created a chunk of size 804, which is longer than the specified 512
# Created a chunk of size 687, which is longer than the specified 512
# Created a chunk of size 559, which is longer than the specified 512
# Created a chunk of size 825, which is longer than the specified 512
# Created a chunk of size 519, which is longer than the specified 512
# Created a chunk of size 675, which is longer than the specified 512
# Created a chunk of size 518, which is longer than the specified 512
# Created a chunk of size 565, which is longer than the specified 512
# Created a chunk of size 520, which is longer than the specified 512
# Created a chunk of size 533, which is longer than the specified 512
# Created a chunk of size 769, which is longer than the specified 512
# Created a chunk of size 668, which is longer than the specified 512
# Created a chunk of size 678, which is longer than the specified 512
# Created a chunk of size 756, which is longer than the specified 512
# Created a chunk of size 815, which is longer than the specified 512
# Created a chunk of size 4738, which is longer than the specified 512
# Created a chunk of size 520, which is longer than the specified 512
# Created a chunk of size 615, which is longer than the specified 512
# Created a chunk of size 651, which is longer than the specified 512
# Created a chunk of size 525, which is longer than the specified 512
# Created a chunk of size 518, which is longer than the specified 512
# Created a chunk of size 1169, which is longer than the specified 512
# Created a chunk of size 588, which is longer than the specified 512
# Created a chunk of size 514, which is longer than the specified 512
# Created a chunk of size 1559, which is longer than the specified 512
# Created a chunk of size 2283, which is longer than the specified 512
# Created a chunk of size 1562, which is longer than the specified 512
# Created a chunk of size 2287, which is longer than the specified 512
# Created a chunk of size 796, which is longer than the specified 512
# Created a chunk of size 652, which is longer than the specified 512
# Created a chunk of size 843, which is longer than the specified 512
# Created a chunk of size 518, which is longer than the specified 512
# Created a chunk of size 1216, which is longer than the specified 512
# Created a chunk of size 661, which is longer than the specified 512
# Created a chunk of size 653, which is longer than the specified 512
# Created a chunk of size 589, which is longer than the specified 512
# Created a chunk of size 544, which is longer than the specified 512
# Created a chunk of size 522, which is longer than the specified 512
# Created a chunk of size 858, which is longer than the specified 512
# Created a chunk of size 843, which is longer than the specified 512
# Created a chunk of size 534, which is longer than the specified 512
# Created a chunk of size 539, which is longer than the specified 512
# Created a chunk of size 582, which is longer than the specified 512
# Created a chunk of size 637, which is longer than the specified 512
# Created a chunk of size 665, which is longer than the specified 512
# Created a chunk of size 577, which is longer than the specified 512
# Created a chunk of size 555, which is longer than the specified 512
# Created a chunk of size 642, which is longer than the specified 512
# Created a chunk of size 668, which is longer than the specified 512
# Created a chunk of size 690, which is longer than the specified 512
# Created a chunk of size 518, which is longer than the specified 512
# Created a chunk of size 656, which is longer than the specified 512
# Created a chunk of size 682, which is longer than the specified 512
# Created a chunk of size 963, which is longer than the specified 512
# Created a chunk of size 603, which is longer than the specified 512
# Created a chunk of size 969, which is longer than the specified 512

# %%
print(f"Number documents {len(documents)}")
print(f"Number chunks {len(document_chunks)}")
# Out:
# Number documents 1157
# Number chunks 12331

# %%
# add 'Context' and 'Source' labels to the document chunks 
document_chunks = [f"Context: {chunk.page_content} Source: {chunk.metadata['source']}" for chunk in document_chunks]

# %%
# convert document chunks to a dataframe 
embeddings_df = pd.DataFrame(document_chunks, columns =['text'])
embeddings_df.shape
# Out:
# (12331, 1)

# %%
embeddings_df[995:1000]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            text
# 995                                                                                                 Context: Function\napoc.path.expand  \nReturns paths expanded from the start node following the given relationship types from min-depth to max-depth.\nProcedure\napoc.path.expandConfig  \nReturns paths expanded from the start node the given relationship types from min-depth to max-depth.\nProcedure\napoc.path.slice  \nReturns a sub-path of the given length and offset from the given path.\nFunction\napoc.path.spanningTree Source: https://neo4j.com/docs/aura/platform/apoc/
# 996                    Context: Function\napoc.path.spanningTree  \nReturns spanning tree paths expanded from the start node following the given relationship types to max-depth.\nProcedure\napoc.path.subgraphAll  \nReturns the sub-graph reachable from the start node following the given relationship types to max-depth.\nProcedure\napoc.path.subgraphNodes  \nReturns the nodes in the sub-graph reachable from the start node following the given relationship types to max-depth.\nProcedure\napoc.periodic\napoc.periodic.cancel Source: https://neo4j.com/docs/aura/platform/apoc/
# 997  Context: Procedure\napoc.periodic\napoc.periodic.cancel  \nCancels the given background job.\nProcedure\napoc.periodic.commit  \nRuns the given statement in separate batched transactions.\nProcedure\napoc.periodic.countdown  \nRuns a repeatedly called background statement until it returns 0.\nProcedure\napoc.periodic.iterate  \nRuns the second statement for each item returned by the first statement.\nThis procedure returns the number of batches and the total number of processed rows.\nProcedure\napoc.periodic.list Source: https://neo4j.com/docs/aura/platform/apoc/
# 998                                            Context: Procedure\napoc.periodic.list  \nReturns a list of all background jobs.\nProcedure\napoc.periodic.repeat  \nRuns a repeatedly called background job.\nTo stop this procedure, use apoc.periodic.cancel.\nProcedure\napoc.periodic.submit  \nCreates a background job which runs the given Cypher statement once.\nProcedure\napoc.refactor\napoc.refactor.categorize  \nCreates new category nodes from nodes in the graph with the specified sourceKey as one of its property keys. Source: https://neo4j.com/docs/aura/platform/apoc/
# 999                                                                                                                                       Context: The new category nodes are then connected to the original nodes with a relationship of the given type.\nProcedure\napoc.refactor.cloneNodes  \nClones the given nodes with their labels and properties.\nIt is possible to skip any node properties using skipProperties (note: this only skips properties on nodes and not their relationships).\nProcedure\napoc.refactor.cloneSubgraph Source: https://neo4j.com/docs/aura/platform/apoc/

# %% [markdown]
# *To-do: Explore performing additional pre-processing on the chunked documents to remove newlines, special characters, or other noise that may impact their readability or the quality of embeddings. This will need to be investgated more for future iterations.*

# %% [markdown]
# # Create GCP Text Embeddings using LangChain

# %% [markdown]
# ## Define Error Handling Function

# %%
def handle_quota_errors(func,  *args, retry_delay=5, backoff_factor=2, **kwargs):
    """
    Executes the given function and retries in case of an exception after a delay.

    Args:
        func (callable): The function to be executed.
        *args: Positional arguments to be passed to `func`.
        retry_delay (int, optional): Initial delay before retrying in case of an error. Default is 5 seconds.
        backoff_factor (int, optional): Multiplier for the delay for subsequent retries. Default is 2.
        **kwargs: Keyword arguments to be passed to `func`.

    Returns:
        Any: Document embeddings from function func

    Raises:
        Exception: Any exception raised by `func` if it occurs after exhausting all retries.
    """
    retries = 0

    try:
      return func(*args, **kwargs)
    except Exception as e:
      print(f"error: {e}")
      retries += 1
      wait = retry_delay * (backoff_factor ** retries)
      time.sleep(wait)
      print("wait for {wait} seconds")

# %% [markdown]
# ## Generate Embeddings and Save Document Chunks

# %%
# change to directory to save chunked documents
os.chdir('/home/jupyter/data/doc_chunks_v2')

# %%
# instantiate VertexAI Embeddings function 
embeddings = VertexAIEmbeddings()

# %%
# generate embeddings 
index_embeddings = []

for index, doc in embeddings_df.iterrows():
  # generate embeddings with error handling   
  print(f"Get embedding and write document for document {index} of {len(embeddings_df)-1}")
  embedding = handle_quota_errors(embeddings.embed_query, doc['text'])

  if embedding is not None:
    # create source doc id variable 
    doc_id = f"{index}.txt"
    
    # save doc_id and embedding to a dictionary 
    embedding_dict = {
              "id": doc_id,
              "embedding": [str(value) for value in embedding],
    }
    
    index_embeddings.append(json.dumps(embedding_dict) + "\n")

    # write source doc chunk text to local directory 
    doc_id = f"{index}.txt"
    with open(f"{doc_id}", "w") as document:
      document.write(doc['text'])
# Out:
# Get embedding and write document for document 0 of 12316
# Get embedding and write document for document 1 of 12316
# Get embedding and write document for document 2 of 12316
# Get embedding and write document for document 3 of 12316
# Get embedding and write document for document 4 of 12316
# Get embedding and write document for document 5 of 12316
# Get embedding and write document for document 6 of 12316
# Get embedding and write document for document 7 of 12316
# Get embedding and write document for document 8 of 12316
# Get embedding and write document for document 9 of 12316
# Get embedding and write document for document 10 of 12316
# Get embedding and write document for document 11 of 12316
# Get embedding and write document for document 12 of 12316
# Get embedding and write document for document 13 of 12316
# Get embedding and write document for document 14 of 12316
# Get embedding and write document for document 15 of 12316
# Get embedding and write document for document 16 of 12316
# Get embedding and write document for document 17 of 12316
# Get embedding and write document for document 18 of 12316
# Get embedding and write document for document 19 of 12316
# Get embedding and write document for document 20 of 12316
# Get embedding and write document for document 21 of 12316
# Get embedding and write document for document 22 of 12316
# Get embedding and write document for document 23 of 12316
# Get embedding and write document for document 24 of 12316
# Get embedding and write document for document 25 of 12316
# Get embedding and write document for document 26 of 12316
# Get embedding and write document for document 27 of 12316
# Get embedding and write document for document 28 of 12316
# Get embedding and write document for document 29 of 12316
# Get embedding and write document for document 30 of 12316
# Get embedding and write document for document 31 of 12316
# Get embedding and write document for document 32 of 12316
# Get embedding and write document for document 33 of 12316
# Get embedding and write document for document 34 of 12316
# Get embedding and write document for document 35 of 12316
# Get embedding and write document for document 36 of 12316
# Get embedding and write document for document 37 of 12316
# Get embedding and write document for document 38 of 12316
# Get embedding and write document for document 39 of 12316
# Get embedding and write document for document 40 of 12316
# Get embedding and write document for document 41 of 12316
# Get embedding and write document for document 42 of 12316
# Get embedding and write document for document 43 of 12316
# Get embedding and write document for document 44 of 12316
# Get embedding and write document for document 45 of 12316
# Get embedding and write document for document 46 of 12316
# Get embedding and write document for document 47 of 12316
# Get embedding and write document for document 48 of 12316
# Get embedding and write document for document 49 of 12316
# Get embedding and write document for document 50 of 12316
# Get embedding and write document for document 51 of 12316
# Get embedding and write document for document 52 of 12316
# Get embedding and write document for document 53 of 12316
# Get embedding and write document for document 54 of 12316
# Get embedding and write document for document 55 of 12316
# Get embedding and write document for document 56 of 12316
# Get embedding and write document for document 57 of 12316
# Get embedding and write document for document 58 of 12316
# Get embedding and write document for document 59 of 12316
# Get embedding and write document for document 60 of 12316
# Get embedding and write document for document 61 of 12316
# Get embedding and write document for document 62 of 12316
# Get embedding and write document for document 63 of 12316
# Get embedding and write document for document 64 of 12316
# Get embedding and write document for document 65 of 12316
# Get embedding and write document for document 66 of 12316
# Get embedding and write document for document 67 of 12316
# Get embedding and write document for document 68 of 12316
# Get embedding and write document for document 69 of 12316
# Get embedding and write document for document 70 of 12316
# Get embedding and write document for document 71 of 12316
# Get embedding and write document for document 72 of 12316
# Get embedding and write document for document 73 of 12316
# Get embedding and write document for document 74 of 12316
# Get embedding and write document for document 75 of 12316
# Get embedding and write document for document 76 of 12316
# Get embedding and write document for document 77 of 12316
# Get embedding and write document for document 78 of 12316
# Get embedding and write document for document 79 of 12316
# Get embedding and write document for document 80 of 12316
# Get embedding and write document for document 81 of 12316
# Get embedding and write document for document 82 of 12316
# Get embedding and write document for document 83 of 12316
# Get embedding and write document for document 84 of 12316
# Get embedding and write document for document 85 of 12316
# Get embedding and write document for document 86 of 12316
# Get embedding and write document for document 87 of 12316
# Get embedding and write document for document 88 of 12316
# Get embedding and write document for document 89 of 12316
# Get embedding and write document for document 90 of 12316
# Get embedding and write document for document 91 of 12316
# Get embedding and write document for document 92 of 12316
# Get embedding and write document for document 93 of 12316
# Get embedding and write document for document 94 of 12316
# Get embedding and write document for document 95 of 12316
# Get embedding and write document for document 96 of 12316
# Get embedding and write document for document 97 of 12316
# Get embedding and write document for document 98 of 12316
# Get embedding and write document for document 99 of 12316
# Get embedding and write document for document 100 of 12316
# Get embedding and write document for document 101 of 12316
# Get embedding and write document for document 102 of 12316
# Get embedding and write document for document 103 of 12316
# Get embedding and write document for document 104 of 12316
# Get embedding and write document for document 105 of 12316
# Get embedding and write document for document 106 of 12316
# Get embedding and write document for document 107 of 12316
# Get embedding and write document for document 108 of 12316
# Get embedding and write document for document 109 of 12316
# Get embedding and write document for document 110 of 12316
# Get embedding and write document for document 111 of 12316
# Get embedding and write document for document 112 of 12316
# Get embedding and write document for document 113 of 12316
# Get embedding and write document for document 114 of 12316
# Get embedding and write document for document 115 of 12316
# Get embedding and write document for document 116 of 12316
# Get embedding and write document for document 117 of 12316
# Get embedding and write document for document 118 of 12316
# Get embedding and write document for document 119 of 12316
# Get embedding and write document for document 120 of 12316
# Get embedding and write document for document 121 of 12316
# Get embedding and write document for document 122 of 12316
# Get embedding and write document for document 123 of 12316
# Get embedding and write document for document 124 of 12316
# Get embedding and write document for document 125 of 12316
# Get embedding and write document for document 126 of 12316
# Get embedding and write document for document 127 of 12316
# Get embedding and write document for document 128 of 12316
# Get embedding and write document for document 129 of 12316
# Get embedding and write document for document 130 of 12316
# Get embedding and write document for document 131 of 12316
# Get embedding and write document for document 132 of 12316
# Get embedding and write document for document 133 of 12316
# Get embedding and write document for document 134 of 12316
# Get embedding and write document for document 135 of 12316
# Get embedding and write document for document 136 of 12316
# Get embedding and write document for document 137 of 12316
# Get embedding and write document for document 138 of 12316
# Get embedding and write document for document 139 of 12316
# Get embedding and write document for document 140 of 12316
# Get embedding and write document for document 141 of 12316
# Get embedding and write document for document 142 of 12316
# Get embedding and write document for document 143 of 12316
# Get embedding and write document for document 144 of 12316
# Get embedding and write document for document 145 of 12316
# Get embedding and write document for document 146 of 12316
# Get embedding and write document for document 147 of 12316
# Get embedding and write document for document 148 of 12316
# Get embedding and write document for document 149 of 12316
# Get embedding and write document for document 150 of 12316
# Get embedding and write document for document 151 of 12316
# Get embedding and write document for document 152 of 12316
# Get embedding and write document for document 153 of 12316
# Get embedding and write document for document 154 of 12316
# Get embedding and write document for document 155 of 12316
# Get embedding and write document for document 156 of 12316
# Get embedding and write document for document 157 of 12316
# Get embedding and write document for document 158 of 12316
# Get embedding and write document for document 159 of 12316
# Get embedding and write document for document 160 of 12316
# Get embedding and write document for document 161 of 12316
# Get embedding and write document for document 162 of 12316
# Get embedding and write document for document 163 of 12316
# Get embedding and write document for document 164 of 12316
# Get embedding and write document for document 165 of 12316
# Get embedding and write document for document 166 of 12316
# Get embedding and write document for document 167 of 12316
# Get embedding and write document for document 168 of 12316
# Get embedding and write document for document 169 of 12316
# Get embedding and write document for document 170 of 12316
# Get embedding and write document for document 171 of 12316
# Get embedding and write document for document 172 of 12316
# Get embedding and write document for document 173 of 12316
# Get embedding and write document for document 174 of 12316
# Get embedding and write document for document 175 of 12316
# Get embedding and write document for document 176 of 12316
# Get embedding and write document for document 177 of 12316
# Get embedding and write document for document 178 of 12316
# Get embedding and write document for document 179 of 12316
# Get embedding and write document for document 180 of 12316
# Get embedding and write document for document 181 of 12316
# Get embedding and write document for document 182 of 12316
# Get embedding and write document for document 183 of 12316
# Get embedding and write document for document 184 of 12316
# Get embedding and write document for document 185 of 12316
# Get embedding and write document for document 186 of 12316
# Get embedding and write document for document 187 of 12316
# Get embedding and write document for document 188 of 12316
# Get embedding and write document for document 189 of 12316
# Get embedding and write document for document 190 of 12316
# Get embedding and write document for document 191 of 12316
# Get embedding and write document for document 192 of 12316
# Get embedding and write document for document 193 of 12316
# Get embedding and write document for document 194 of 12316
# Get embedding and write document for document 195 of 12316
# Get embedding and write document for document 196 of 12316
# Get embedding and write document for document 197 of 12316
# Get embedding and write document for document 198 of 12316
# Get embedding and write document for document 199 of 12316
# Get embedding and write document for document 200 of 12316
# Get embedding and write document for document 201 of 12316
# Get embedding and write document for document 202 of 12316
# Get embedding and write document for document 203 of 12316
# Get embedding and write document for document 204 of 12316
# Get embedding and write document for document 205 of 12316
# Get embedding and write document for document 206 of 12316
# Get embedding and write document for document 207 of 12316
# Get embedding and write document for document 208 of 12316
# Get embedding and write document for document 209 of 12316
# Get embedding and write document for document 210 of 12316
# Get embedding and write document for document 211 of 12316
# Get embedding and write document for document 212 of 12316
# Get embedding and write document for document 213 of 12316
# Get embedding and write document for document 214 of 12316
# Get embedding and write document for document 215 of 12316
# Get embedding and write document for document 216 of 12316
# Get embedding and write document for document 217 of 12316
# Get embedding and write document for document 218 of 12316
# Get embedding and write document for document 219 of 12316
# Get embedding and write document for document 220 of 12316
# Get embedding and write document for document 221 of 12316
# Get embedding and write document for document 222 of 12316
# Get embedding and write document for document 223 of 12316
# Get embedding and write document for document 224 of 12316
# Get embedding and write document for document 225 of 12316
# Get embedding and write document for document 226 of 12316
# Get embedding and write document for document 227 of 12316
# Get embedding and write document for document 228 of 12316
# Get embedding and write document for document 229 of 12316
# Get embedding and write document for document 230 of 12316
# Get embedding and write document for document 231 of 12316
# Get embedding and write document for document 232 of 12316
# Get embedding and write document for document 233 of 12316
# Get embedding and write document for document 234 of 12316
# Get embedding and write document for document 235 of 12316
# Get embedding and write document for document 236 of 12316
# Get embedding and write document for document 237 of 12316
# Get embedding and write document for document 238 of 12316
# Get embedding and write document for document 239 of 12316
# Get embedding and write document for document 240 of 12316
# Get embedding and write document for document 241 of 12316
# Get embedding and write document for document 242 of 12316
# Get embedding and write document for document 243 of 12316
# Get embedding and write document for document 244 of 12316
# Get embedding and write document for document 245 of 12316
# Get embedding and write document for document 246 of 12316
# Get embedding and write document for document 247 of 12316
# Get embedding and write document for document 248 of 12316
# Get embedding and write document for document 249 of 12316
# Get embedding and write document for document 250 of 12316
# Get embedding and write document for document 251 of 12316
# Get embedding and write document for document 252 of 12316
# Get embedding and write document for document 253 of 12316
# Get embedding and write document for document 254 of 12316
# Get embedding and write document for document 255 of 12316
# Get embedding and write document for document 256 of 12316
# Get embedding and write document for document 257 of 12316
# Get embedding and write document for document 258 of 12316
# Get embedding and write document for document 259 of 12316
# Get embedding and write document for document 260 of 12316
# Get embedding and write document for document 261 of 12316
# Get embedding and write document for document 262 of 12316
# Get embedding and write document for document 263 of 12316
# Get embedding and write document for document 264 of 12316
# Get embedding and write document for document 265 of 12316
# Get embedding and write document for document 266 of 12316
# Get embedding and write document for document 267 of 12316
# Get embedding and write document for document 268 of 12316
# Get embedding and write document for document 269 of 12316
# Get embedding and write document for document 270 of 12316
# Get embedding and write document for document 271 of 12316
# Get embedding and write document for document 272 of 12316
# Get embedding and write document for document 273 of 12316
# Get embedding and write document for document 274 of 12316
# Get embedding and write document for document 275 of 12316
# Get embedding and write document for document 276 of 12316
# Get embedding and write document for document 277 of 12316
# Get embedding and write document for document 278 of 12316
# Get embedding and write document for document 279 of 12316
# Get embedding and write document for document 280 of 12316
# Get embedding and write document for document 281 of 12316
# Get embedding and write document for document 282 of 12316
# Get embedding and write document for document 283 of 12316
# Get embedding and write document for document 284 of 12316
# Get embedding and write document for document 285 of 12316
# Get embedding and write document for document 286 of 12316
# Get embedding and write document for document 287 of 12316
# Get embedding and write document for document 288 of 12316
# Get embedding and write document for document 289 of 12316
# Get embedding and write document for document 290 of 12316
# Get embedding and write document for document 291 of 12316
# Get embedding and write document for document 292 of 12316
# Get embedding and write document for document 293 of 12316
# Get embedding and write document for document 294 of 12316
# Get embedding and write document for document 295 of 12316
# Get embedding and write document for document 296 of 12316
# Get embedding and write document for document 297 of 12316
# Get embedding and write document for document 298 of 12316
# Get embedding and write document for document 299 of 12316
# Get embedding and write document for document 300 of 12316
# Get embedding and write document for document 301 of 12316
# Get embedding and write document for document 302 of 12316
# Get embedding and write document for document 303 of 12316
# Get embedding and write document for document 304 of 12316
# Get embedding and write document for document 305 of 12316
# Get embedding and write document for document 306 of 12316
# Get embedding and write document for document 307 of 12316
# Get embedding and write document for document 308 of 12316
# Get embedding and write document for document 309 of 12316
# Get embedding and write document for document 310 of 12316
# Get embedding and write document for document 311 of 12316
# Get embedding and write document for document 312 of 12316
# Get embedding and write document for document 313 of 12316
# Get embedding and write document for document 314 of 12316
# Get embedding and write document for document 315 of 12316
# Get embedding and write document for document 316 of 12316
# Get embedding and write document for document 317 of 12316
# Get embedding and write document for document 318 of 12316
# Get embedding and write document for document 319 of 12316
# Get embedding and write document for document 320 of 12316
# Get embedding and write document for document 321 of 12316
# Get embedding and write document for document 322 of 12316
# Get embedding and write document for document 323 of 12316
# Get embedding and write document for document 324 of 12316
# Get embedding and write document for document 325 of 12316
# Get embedding and write document for document 326 of 12316
# Get embedding and write document for document 327 of 12316
# Get embedding and write document for document 328 of 12316
# Get embedding and write document for document 329 of 12316
# Get embedding and write document for document 330 of 12316
# Get embedding and write document for document 331 of 12316
# Get embedding and write document for document 332 of 12316
# Get embedding and write document for document 333 of 12316
# Get embedding and write document for document 334 of 12316
# Get embedding and write document for document 335 of 12316
# Get embedding and write document for document 336 of 12316
# Get embedding and write document for document 337 of 12316
# Get embedding and write document for document 338 of 12316
# Get embedding and write document for document 339 of 12316
# Get embedding and write document for document 340 of 12316
# Get embedding and write document for document 341 of 12316
# Get embedding and write document for document 342 of 12316
# Get embedding and write document for document 343 of 12316
# Get embedding and write document for document 344 of 12316
# Get embedding and write document for document 345 of 12316
# Get embedding and write document for document 346 of 12316
# Get embedding and write document for document 347 of 12316
# Get embedding and write document for document 348 of 12316
# Get embedding and write document for document 349 of 12316
# Get embedding and write document for document 350 of 12316
# Get embedding and write document for document 351 of 12316
# Get embedding and write document for document 352 of 12316
# Get embedding and write document for document 353 of 12316
# Get embedding and write document for document 354 of 12316
# Get embedding and write document for document 355 of 12316
# Get embedding and write document for document 356 of 12316
# Get embedding and write document for document 357 of 12316
# Get embedding and write document for document 358 of 12316
# Get embedding and write document for document 359 of 12316
# Get embedding and write document for document 360 of 12316
# Get embedding and write document for document 361 of 12316
# Get embedding and write document for document 362 of 12316
# Get embedding and write document for document 363 of 12316
# Get embedding and write document for document 364 of 12316
# Get embedding and write document for document 365 of 12316
# Get embedding and write document for document 366 of 12316
# Get embedding and write document for document 367 of 12316
# Get embedding and write document for document 368 of 12316
# Get embedding and write document for document 369 of 12316
# Get embedding and write document for document 370 of 12316
# Get embedding and write document for document 371 of 12316
# Get embedding and write document for document 372 of 12316
# Get embedding and write document for document 373 of 12316
# Get embedding and write document for document 374 of 12316
# Get embedding and write document for document 375 of 12316
# Get embedding and write document for document 376 of 12316
# Get embedding and write document for document 377 of 12316
# Get embedding and write document for document 378 of 12316
# Get embedding and write document for document 379 of 12316
# Get embedding and write document for document 380 of 12316
# Get embedding and write document for document 381 of 12316
# Get embedding and write document for document 382 of 12316
# Get embedding and write document for document 383 of 12316
# Get embedding and write document for document 384 of 12316
# Get embedding and write document for document 385 of 12316
# Get embedding and write document for document 386 of 12316
# Get embedding and write document for document 387 of 12316
# Get embedding and write document for document 388 of 12316
# Get embedding and write document for document 389 of 12316
# Get embedding and write document for document 390 of 12316
# Get embedding and write document for document 391 of 12316
# Get embedding and write document for document 392 of 12316
# Get embedding and write document for document 393 of 12316
# Get embedding and write document for document 394 of 12316
# Get embedding and write document for document 395 of 12316
# Get embedding and write document for document 396 of 12316
# Get embedding and write document for document 397 of 12316
# Get embedding and write document for document 398 of 12316
# Get embedding and write document for document 399 of 12316
# Get embedding and write document for document 400 of 12316
# Get embedding and write document for document 401 of 12316
# Get embedding and write document for document 402 of 12316
# Get embedding and write document for document 403 of 12316
# Get embedding and write document for document 404 of 12316
# Get embedding and write document for document 405 of 12316
# Get embedding and write document for document 406 of 12316
# Get embedding and write document for document 407 of 12316
# Get embedding and write document for document 408 of 12316
# Get embedding and write document for document 409 of 12316
# Get embedding and write document for document 410 of 12316
# Get embedding and write document for document 411 of 12316
# Get embedding and write document for document 412 of 12316
# Get embedding and write document for document 413 of 12316
# Get embedding and write document for document 414 of 12316
# Get embedding and write document for document 415 of 12316
# Get embedding and write document for document 416 of 12316
# Get embedding and write document for document 417 of 12316
# Get embedding and write document for document 418 of 12316
# Get embedding and write document for document 419 of 12316
# Get embedding and write document for document 420 of 12316
# Get embedding and write document for document 421 of 12316
# Get embedding and write document for document 422 of 12316
# Get embedding and write document for document 423 of 12316
# Get embedding and write document for document 424 of 12316
# Get embedding and write document for document 425 of 12316
# Get embedding and write document for document 426 of 12316
# Get embedding and write document for document 427 of 12316
# Get embedding and write document for document 428 of 12316
# Get embedding and write document for document 429 of 12316
# Get embedding and write document for document 430 of 12316
# Get embedding and write document for document 431 of 12316
# Get embedding and write document for document 432 of 12316
# Get embedding and write document for document 433 of 12316
# Get embedding and write document for document 434 of 12316
# Get embedding and write document for document 435 of 12316
# Get embedding and write document for document 436 of 12316
# Get embedding and write document for document 437 of 12316
# Get embedding and write document for document 438 of 12316
# Get embedding and write document for document 439 of 12316
# Get embedding and write document for document 440 of 12316
# Get embedding and write document for document 441 of 12316
# Get embedding and write document for document 442 of 12316
# Get embedding and write document for document 443 of 12316
# Get embedding and write document for document 444 of 12316
# Get embedding and write document for document 445 of 12316
# Get embedding and write document for document 446 of 12316
# Get embedding and write document for document 447 of 12316
# Get embedding and write document for document 448 of 12316
# Get embedding and write document for document 449 of 12316
# Get embedding and write document for document 450 of 12316
# Get embedding and write document for document 451 of 12316
# Get embedding and write document for document 452 of 12316
# Get embedding and write document for document 453 of 12316
# Get embedding and write document for document 454 of 12316
# Get embedding and write document for document 455 of 12316
# Get embedding and write document for document 456 of 12316
# Get embedding and write document for document 457 of 12316
# Get embedding and write document for document 458 of 12316
# Get embedding and write document for document 459 of 12316
# Get embedding and write document for document 460 of 12316
# Get embedding and write document for document 461 of 12316
# Get embedding and write document for document 462 of 12316
# Get embedding and write document for document 463 of 12316
# Get embedding and write document for document 464 of 12316
# Get embedding and write document for document 465 of 12316
# Get embedding and write document for document 466 of 12316
# Get embedding and write document for document 467 of 12316
# Get embedding and write document for document 468 of 12316
# Get embedding and write document for document 469 of 12316
# Get embedding and write document for document 470 of 12316
# Get embedding and write document for document 471 of 12316
# Get embedding and write document for document 472 of 12316
# Get embedding and write document for document 473 of 12316
# Get embedding and write document for document 474 of 12316
# Get embedding and write document for document 475 of 12316
# Get embedding and write document for document 476 of 12316
# Get embedding and write document for document 477 of 12316
# Get embedding and write document for document 478 of 12316
# Get embedding and write document for document 479 of 12316
# Get embedding and write document for document 480 of 12316
# Get embedding and write document for document 481 of 12316
# Get embedding and write document for document 482 of 12316
# Get embedding and write document for document 483 of 12316
# Get embedding and write document for document 484 of 12316
# Get embedding and write document for document 485 of 12316
# Get embedding and write document for document 486 of 12316
# Get embedding and write document for document 487 of 12316
# Get embedding and write document for document 488 of 12316
# Get embedding and write document for document 489 of 12316
# Get embedding and write document for document 490 of 12316
# Get embedding and write document for document 491 of 12316
# Get embedding and write document for document 492 of 12316
# Get embedding and write document for document 493 of 12316
# Get embedding and write document for document 494 of 12316
# Get embedding and write document for document 495 of 12316
# Get embedding and write document for document 496 of 12316
# Get embedding and write document for document 497 of 12316
# Get embedding and write document for document 498 of 12316
# Get embedding and write document for document 499 of 12316
# Get embedding and write document for document 500 of 12316
# Get embedding and write document for document 501 of 12316
# Get embedding and write document for document 502 of 12316
# Get embedding and write document for document 503 of 12316
# Get embedding and write document for document 504 of 12316
# Get embedding and write document for document 505 of 12316
# Get embedding and write document for document 506 of 12316
# Get embedding and write document for document 507 of 12316
# Get embedding and write document for document 508 of 12316
# Get embedding and write document for document 509 of 12316
# Get embedding and write document for document 510 of 12316
# Get embedding and write document for document 511 of 12316
# Get embedding and write document for document 512 of 12316
# Get embedding and write document for document 513 of 12316
# Get embedding and write document for document 514 of 12316
# Get embedding and write document for document 515 of 12316
# Get embedding and write document for document 516 of 12316
# Get embedding and write document for document 517 of 12316
# Get embedding and write document for document 518 of 12316
# Get embedding and write document for document 519 of 12316
# Get embedding and write document for document 520 of 12316
# Get embedding and write document for document 521 of 12316
# Get embedding and write document for document 522 of 12316
# Get embedding and write document for document 523 of 12316
# Get embedding and write document for document 524 of 12316
# Get embedding and write document for document 525 of 12316
# Get embedding and write document for document 526 of 12316
# Get embedding and write document for document 527 of 12316
# Get embedding and write document for document 528 of 12316
# Get embedding and write document for document 529 of 12316
# Get embedding and write document for document 530 of 12316
# Get embedding and write document for document 531 of 12316
# Get embedding and write document for document 532 of 12316
# Get embedding and write document for document 533 of 12316
# Get embedding and write document for document 534 of 12316
# Get embedding and write document for document 535 of 12316
# Get embedding and write document for document 536 of 12316
# Get embedding and write document for document 537 of 12316
# Get embedding and write document for document 538 of 12316
# Get embedding and write document for document 539 of 12316
# Get embedding and write document for document 540 of 12316
# Get embedding and write document for document 541 of 12316
# Get embedding and write document for document 542 of 12316
# Get embedding and write document for document 543 of 12316
# Get embedding and write document for document 544 of 12316
# Get embedding and write document for document 545 of 12316
# Get embedding and write document for document 546 of 12316
# Get embedding and write document for document 547 of 12316
# Get embedding and write document for document 548 of 12316
# Get embedding and write document for document 549 of 12316
# Get embedding and write document for document 550 of 12316
# Get embedding and write document for document 551 of 12316
# Get embedding and write document for document 552 of 12316
# Get embedding and write document for document 553 of 12316
# Get embedding and write document for document 554 of 12316
# Get embedding and write document for document 555 of 12316
# Get embedding and write document for document 556 of 12316
# Get embedding and write document for document 557 of 12316
# Get embedding and write document for document 558 of 12316
# Get embedding and write document for document 559 of 12316
# Get embedding and write document for document 560 of 12316
# Get embedding and write document for document 561 of 12316
# Get embedding and write document for document 562 of 12316
# Get embedding and write document for document 563 of 12316
# Get embedding and write document for document 564 of 12316
# Get embedding and write document for document 565 of 12316
# Get embedding and write document for document 566 of 12316
# Get embedding and write document for document 567 of 12316
# Get embedding and write document for document 568 of 12316
# Get embedding and write document for document 569 of 12316
# Get embedding and write document for document 570 of 12316
# Get embedding and write document for document 571 of 12316
# Get embedding and write document for document 572 of 12316
# Get embedding and write document for document 573 of 12316
# Get embedding and write document for document 574 of 12316
# Get embedding and write document for document 575 of 12316
# Get embedding and write document for document 576 of 12316
# Get embedding and write document for document 577 of 12316
# Get embedding and write document for document 578 of 12316
# Get embedding and write document for document 579 of 12316
# Get embedding and write document for document 580 of 12316
# Get embedding and write document for document 581 of 12316
# Get embedding and write document for document 582 of 12316
# Get embedding and write document for document 583 of 12316
# Get embedding and write document for document 584 of 12316
# Get embedding and write document for document 585 of 12316
# Get embedding and write document for document 586 of 12316
# Get embedding and write document for document 587 of 12316
# Get embedding and write document for document 588 of 12316
# Get embedding and write document for document 589 of 12316
# Get embedding and write document for document 590 of 12316
# Get embedding and write document for document 591 of 12316
# Get embedding and write document for document 592 of 12316
# Get embedding and write document for document 593 of 12316
# Get embedding and write document for document 594 of 12316
# Get embedding and write document for document 595 of 12316
# Get embedding and write document for document 596 of 12316
# Get embedding and write document for document 597 of 12316
# Get embedding and write document for document 598 of 12316
# Get embedding and write document for document 599 of 12316
# Get embedding and write document for document 600 of 12316
# Get embedding and write document for document 601 of 12316
# Get embedding and write document for document 602 of 12316
# Get embedding and write document for document 603 of 12316
# Get embedding and write document for document 604 of 12316
# Get embedding and write document for document 605 of 12316
# Get embedding and write document for document 606 of 12316
# Get embedding and write document for document 607 of 12316
# Get embedding and write document for document 608 of 12316
# Get embedding and write document for document 609 of 12316
# Get embedding and write document for document 610 of 12316
# Get embedding and write document for document 611 of 12316
# Get embedding and write document for document 612 of 12316
# Get embedding and write document for document 613 of 12316
# Get embedding and write document for document 614 of 12316
# Get embedding and write document for document 615 of 12316
# Get embedding and write document for document 616 of 12316
# Get embedding and write document for document 617 of 12316
# Get embedding and write document for document 618 of 12316
# error: 429 Quota exceeded for aiplatform.googleapis.com/online_prediction_requests_per_base_model with base model: textembedding-gecko. Please submit a quota increase request. https://cloud.google.com/vertex-ai/docs/quotas.
# wait for {wait} seconds
# Get embedding and write document for document 619 of 12316
# error: 429 Quota exceeded for aiplatform.googleapis.com/online_prediction_requests_per_base_model with base model: textembedding-gecko. Please submit a quota increase request. https://cloud.google.com/vertex-ai/docs/quotas.
# wait for {wait} seconds
# Get embedding and write document for document 620 of 12316
# error: 429 Quota exceeded for aiplatform.googleapis.com/online_prediction_requests_per_base_model with base model: textembedding-gecko. Please submit a quota increase request. https://cloud.google.com/vertex-ai/docs/quotas.
# wait for {wait} seconds
# Get embedding and write document for document 621 of 12316
# error: 429 Quota exceeded for aiplatform.googleapis.com/online_prediction_requests_per_base_model with base model: textembedding-gecko. Please submit a quota increase request. https://cloud.google.com/vertex-ai/docs/quotas.
# wait for {wait} seconds
# Get embedding and write document for document 622 of 12316
# Get embedding and write document for document 623 of 12316
# Get embedding and write document for document 624 of 12316
# Get embedding and write document for document 625 of 12316
# Get embedding and write document for document 626 of 12316
# Get embedding and write document for document 627 of 12316
# Get embedding and write document for document 628 of 12316
# Get embedding and write document for document 629 of 12316
# Get embedding and write document for document 630 of 12316
# error: 429 Quota exceeded for aiplatform.googleapis.com/online_prediction_requests_per_base_model with base model: textembedding-gecko. Please submit a quota increase request. https://cloud.google.com/vertex-ai/docs/quotas.
# wait for {wait} seconds
# Get embedding and write document for document 631 of 12316
# Get embedding and write document for document 632 of 12316
# Get embedding and write document for document 633 of 12316
# Get embedding and write document for document 634 of 12316
# Get embedding and write document for document 635 of 12316
# Get embedding and write document for document 636 of 12316
# Get embedding and write document for document 637 of 12316
# Get embedding and write document for document 638 of 12316
# Get embedding and write document for document 639 of 12316
# Get embedding and write document for document 640 of 12316
# Get embedding and write document for document 641 of 12316
# Get embedding and write document for document 642 of 12316
# Get embedding and write document for document 643 of 12316
# Get embedding and write document for document 644 of 12316
# Get embedding and write document for document 645 of 12316
# Get embedding and write document for document 646 of 12316
# Get embedding and write document for document 647 of 12316
# Get embedding and write document for document 648 of 12316
# Get embedding and write document for document 649 of 12316
# Get embedding and write document for document 650 of 12316
# Get embedding and write document for document 651 of 12316
# Get embedding and write document for document 652 of 12316
# Get embedding and write document for document 653 of 12316
# Get embedding and write document for document 654 of 12316
# Get embedding and write document for document 655 of 12316
# Get embedding and write document for document 656 of 12316
# Get embedding and write document for document 657 of 12316
# Get embedding and write document for document 658 of 12316
# Get embedding and write document for document 659 of 12316
# Get embedding and write document for document 660 of 12316
# Get embedding and write document for document 661 of 12316
# Get embedding and write document for document 662 of 12316
# Get embedding and write document for document 663 of 12316
# Get embedding and write document for document 664 of 12316
# Get embedding and write document for document 665 of 12316
# Get embedding and write document for document 666 of 12316
# Get embedding and write document for document 667 of 12316
# Get embedding and write document for document 668 of 12316
# Get embedding and write document for document 669 of 12316
# Get embedding and write document for document 670 of 12316
# Get embedding and write document for document 671 of 12316
# Get embedding and write document for document 672 of 12316
# Get embedding and write document for document 673 of 12316
# Get embedding and write document for document 674 of 12316
# Get embedding and write document for document 675 of 12316
# Get embedding and write document for document 676 of 12316
# Get embedding and write document for document 677 of 12316
# Get embedding and write document for document 678 of 12316
# Get embedding and write document for document 679 of 12316
# Get embedding and write document for document 680 of 12316
# Get embedding and write document for document 681 of 12316
# Get embedding and write document for document 682 of 12316
# Get embedding and write document for document 683 of 12316
# Get embedding and write document for document 684 of 12316
# Get embedding and write document for document 685 of 12316
# Get embedding and write document for document 686 of 12316
# Get embedding and write document for document 687 of 12316
# Get embedding and write document for document 688 of 12316
# Get embedding and write document for document 689 of 12316
# Get embedding and write document for document 690 of 12316
# Get embedding and write document for document 691 of 12316
# Get embedding and write document for document 692 of 12316
# Get embedding and write document for document 693 of 12316
# Get embedding and write document for document 694 of 12316
# Get embedding and write document for document 695 of 12316
# Get embedding and write document for document 696 of 12316
# Get embedding and write document for document 697 of 12316
# Get embedding and write document for document 698 of 12316
# Get embedding and write document for document 699 of 12316
# Get embedding and write document for document 700 of 12316
# Get embedding and write document for document 701 of 12316
# Get embedding and write document for document 702 of 12316
# Get embedding and write document for document 703 of 12316
# Get embedding and write document for document 704 of 12316
# Get embedding and write document for document 705 of 12316
# Get embedding and write document for document 706 of 12316
# Get embedding and write document for document 707 of 12316
# Get embedding and write document for document 708 of 12316
# Get embedding and write document for document 709 of 12316
# Get embedding and write document for document 710 of 12316
# Get embedding and write document for document 711 of 12316
# Get embedding and write document for document 712 of 12316
# Get embedding and write document for document 713 of 12316
# Get embedding and write document for document 714 of 12316
# Get embedding and write document for document 715 of 12316
# Get embedding and write document for document 716 of 12316
# Get embedding and write document for document 717 of 12316
# Get embedding and write document for document 718 of 12316
# Get embedding and write document for document 719 of 12316
# Get embedding and write document for document 720 of 12316
# Get embedding and write document for document 721 of 12316
# Get embedding and write document for document 722 of 12316
# Get embedding and write document for document 723 of 12316
# Get embedding and write document for document 724 of 12316
# Get embedding and write document for document 725 of 12316
# Get embedding and write document for document 726 of 12316
# Get embedding and write document for document 727 of 12316
# Get embedding and write document for document 728 of 12316
# Get embedding and write document for document 729 of 12316
# Get embedding and write document for document 730 of 12316
# Get embedding and write document for document 731 of 12316
# Get embedding and write document for document 732 of 12316
# Get embedding and write document for document 733 of 12316
# Get embedding and write document for document 734 of 12316
# Get embedding and write document for document 735 of 12316
# Get embedding and write document for document 736 of 12316
# Get embedding and write document for document 737 of 12316
# Get embedding and write document for document 738 of 12316
# Get embedding and write document for document 739 of 12316
# Get embedding and write document for document 740 of 12316
# Get embedding and write document for document 741 of 12316
# Get embedding and write document for document 742 of 12316
# Get embedding and write document for document 743 of 12316
# Get embedding and write document for document 744 of 12316
# Get embedding and write document for document 745 of 12316
# Get embedding and write document for document 746 of 12316
# Get embedding and write document for document 747 of 12316
# Get embedding and write document for document 748 of 12316
# Get embedding and write document for document 749 of 12316
# Get embedding and write document for document 750 of 12316
# Get embedding and write document for document 751 of 12316
# Get embedding and write document for document 752 of 12316
# Get embedding and write document for document 753 of 12316
# Get embedding and write document for document 754 of 12316
# Get embedding and write document for document 755 of 12316
# Get embedding and write document for document 756 of 12316
# Get embedding and write document for document 757 of 12316
# Get embedding and write document for document 758 of 12316
# Get embedding and write document for document 759 of 12316
# Get embedding and write document for document 760 of 12316
# Get embedding and write document for document 761 of 12316
# Get embedding and write document for document 762 of 12316
# Get embedding and write document for document 763 of 12316
# Get embedding and write document for document 764 of 12316
# Get embedding and write document for document 765 of 12316
# Get embedding and write document for document 766 of 12316
# Get embedding and write document for document 767 of 12316
# Get embedding and write document for document 768 of 12316
# Get embedding and write document for document 769 of 12316
# Get embedding and write document for document 770 of 12316
# Get embedding and write document for document 771 of 12316
# Get embedding and write document for document 772 of 12316
# Get embedding and write document for document 773 of 12316
# Get embedding and write document for document 774 of 12316
# Get embedding and write document for document 775 of 12316
# Get embedding and write document for document 776 of 12316
# Get embedding and write document for document 777 of 12316
# Get embedding and write document for document 778 of 12316
# Get embedding and write document for document 779 of 12316
# Get embedding and write document for document 780 of 12316
# Get embedding and write document for document 781 of 12316
# Get embedding and write document for document 782 of 12316
# Get embedding and write document for document 783 of 12316
# Get embedding and write document for document 784 of 12316
# Get embedding and write document for document 785 of 12316
# Get embedding and write document for document 786 of 12316
# Get embedding and write document for document 787 of 12316
# Get embedding and write document for document 788 of 12316
# Get embedding and write document for document 789 of 12316
# Get embedding and write document for document 790 of 12316
# Get embedding and write document for document 791 of 12316
# Get embedding and write document for document 792 of 12316
# Get embedding and write document for document 793 of 12316
# ...
# Get embedding and write document for document 11541 of 12316
# Get embedding and write document for document 11542 of 12316
# Get embedding and write document for document 11543 of 12316
# Get embedding and write document for document 11544 of 12316
# Get embedding and write document for document 11545 of 12316
# Get embedding and write document for document 11546 of 12316
# Get embedding and write document for document 11547 of 12316
# Get embedding and write document for document 11548 of 12316
# Get embedding and write document for document 11549 of 12316
# Get embedding and write document for document 11550 of 12316
# Get embedding and write document for document 11551 of 12316
# Get embedding and write document for document 11552 of 12316
# Get embedding and write document for document 11553 of 12316
# Get embedding and write document for document 11554 of 12316
# Get embedding and write document for document 11555 of 12316
# Get embedding and write document for document 11556 of 12316
# Get embedding and write document for document 11557 of 12316
# Get embedding and write document for document 11558 of 12316
# Get embedding and write document for document 11559 of 12316
# Get embedding and write document for document 11560 of 12316
# Get embedding and write document for document 11561 of 12316
# Get embedding and write document for document 11562 of 12316
# Get embedding and write document for document 11563 of 12316
# Get embedding and write document for document 11564 of 12316
# Get embedding and write document for document 11565 of 12316
# Get embedding and write document for document 11566 of 12316
# Get embedding and write document for document 11567 of 12316
# Get embedding and write document for document 11568 of 12316
# Get embedding and write document for document 11569 of 12316
# Get embedding and write document for document 11570 of 12316
# Get embedding and write document for document 11571 of 12316
# Get embedding and write document for document 11572 of 12316
# Get embedding and write document for document 11573 of 12316
# Get embedding and write document for document 11574 of 12316
# Get embedding and write document for document 11575 of 12316
# Get embedding and write document for document 11576 of 12316
# Get embedding and write document for document 11577 of 12316
# Get embedding and write document for document 11578 of 12316
# Get embedding and write document for document 11579 of 12316
# Get embedding and write document for document 11580 of 12316
# Get embedding and write document for document 11581 of 12316
# Get embedding and write document for document 11582 of 12316
# Get embedding and write document for document 11583 of 12316
# Get embedding and write document for document 11584 of 12316
# Get embedding and write document for document 11585 of 12316
# Get embedding and write document for document 11586 of 12316
# Get embedding and write document for document 11587 of 12316
# Get embedding and write document for document 11588 of 12316
# Get embedding and write document for document 11589 of 12316
# Get embedding and write document for document 11590 of 12316
# Get embedding and write document for document 11591 of 12316
# Get embedding and write document for document 11592 of 12316
# Get embedding and write document for document 11593 of 12316
# Get embedding and write document for document 11594 of 12316
# Get embedding and write document for document 11595 of 12316
# Get embedding and write document for document 11596 of 12316
# Get embedding and write document for document 11597 of 12316
# Get embedding and write document for document 11598 of 12316
# Get embedding and write document for document 11599 of 12316
# Get embedding and write document for document 11600 of 12316
# Get embedding and write document for document 11601 of 12316
# Get embedding and write document for document 11602 of 12316
# Get embedding and write document for document 11603 of 12316
# Get embedding and write document for document 11604 of 12316
# Get embedding and write document for document 11605 of 12316
# Get embedding and write document for document 11606 of 12316
# Get embedding and write document for document 11607 of 12316
# Get embedding and write document for document 11608 of 12316
# Get embedding and write document for document 11609 of 12316
# Get embedding and write document for document 11610 of 12316
# Get embedding and write document for document 11611 of 12316
# Get embedding and write document for document 11612 of 12316
# Get embedding and write document for document 11613 of 12316
# Get embedding and write document for document 11614 of 12316
# Get embedding and write document for document 11615 of 12316
# Get embedding and write document for document 11616 of 12316
# Get embedding and write document for document 11617 of 12316
# Get embedding and write document for document 11618 of 12316
# Get embedding and write document for document 11619 of 12316
# Get embedding and write document for document 11620 of 12316
# Get embedding and write document for document 11621 of 12316
# Get embedding and write document for document 11622 of 12316
# Get embedding and write document for document 11623 of 12316
# Get embedding and write document for document 11624 of 12316
# Get embedding and write document for document 11625 of 12316
# Get embedding and write document for document 11626 of 12316
# Get embedding and write document for document 11627 of 12316
# Get embedding and write document for document 11628 of 12316
# Get embedding and write document for document 11629 of 12316
# Get embedding and write document for document 11630 of 12316
# Get embedding and write document for document 11631 of 12316
# Get embedding and write document for document 11632 of 12316
# Get embedding and write document for document 11633 of 12316
# Get embedding and write document for document 11634 of 12316
# Get embedding and write document for document 11635 of 12316
# Get embedding and write document for document 11636 of 12316
# Get embedding and write document for document 11637 of 12316
# Get embedding and write document for document 11638 of 12316
# Get embedding and write document for document 11639 of 12316
# Get embedding and write document for document 11640 of 12316
# Get embedding and write document for document 11641 of 12316
# Get embedding and write document for document 11642 of 12316
# Get embedding and write document for document 11643 of 12316
# Get embedding and write document for document 11644 of 12316
# Get embedding and write document for document 11645 of 12316
# Get embedding and write document for document 11646 of 12316
# Get embedding and write document for document 11647 of 12316
# Get embedding and write document for document 11648 of 12316
# Get embedding and write document for document 11649 of 12316
# Get embedding and write document for document 11650 of 12316
# Get embedding and write document for document 11651 of 12316
# Get embedding and write document for document 11652 of 12316
# Get embedding and write document for document 11653 of 12316
# Get embedding and write document for document 11654 of 12316
# Get embedding and write document for document 11655 of 12316
# Get embedding and write document for document 11656 of 12316
# Get embedding and write document for document 11657 of 12316
# Get embedding and write document for document 11658 of 12316
# Get embedding and write document for document 11659 of 12316
# Get embedding and write document for document 11660 of 12316
# Get embedding and write document for document 11661 of 12316
# Get embedding and write document for document 11662 of 12316
# Get embedding and write document for document 11663 of 12316
# Get embedding and write document for document 11664 of 12316
# Get embedding and write document for document 11665 of 12316
# Get embedding and write document for document 11666 of 12316
# Get embedding and write document for document 11667 of 12316
# Get embedding and write document for document 11668 of 12316
# Get embedding and write document for document 11669 of 12316
# Get embedding and write document for document 11670 of 12316
# Get embedding and write document for document 11671 of 12316
# Get embedding and write document for document 11672 of 12316
# Get embedding and write document for document 11673 of 12316
# Get embedding and write document for document 11674 of 12316
# Get embedding and write document for document 11675 of 12316
# Get embedding and write document for document 11676 of 12316
# Get embedding and write document for document 11677 of 12316
# Get embedding and write document for document 11678 of 12316
# Get embedding and write document for document 11679 of 12316
# Get embedding and write document for document 11680 of 12316
# Get embedding and write document for document 11681 of 12316
# Get embedding and write document for document 11682 of 12316
# Get embedding and write document for document 11683 of 12316
# Get embedding and write document for document 11684 of 12316
# Get embedding and write document for document 11685 of 12316
# Get embedding and write document for document 11686 of 12316
# Get embedding and write document for document 11687 of 12316
# Get embedding and write document for document 11688 of 12316
# Get embedding and write document for document 11689 of 12316
# Get embedding and write document for document 11690 of 12316
# Get embedding and write document for document 11691 of 12316
# Get embedding and write document for document 11692 of 12316
# Get embedding and write document for document 11693 of 12316
# Get embedding and write document for document 11694 of 12316
# Get embedding and write document for document 11695 of 12316
# Get embedding and write document for document 11696 of 12316
# Get embedding and write document for document 11697 of 12316
# Get embedding and write document for document 11698 of 12316
# Get embedding and write document for document 11699 of 12316
# Get embedding and write document for document 11700 of 12316
# Get embedding and write document for document 11701 of 12316
# Get embedding and write document for document 11702 of 12316
# Get embedding and write document for document 11703 of 12316
# Get embedding and write document for document 11704 of 12316
# Get embedding and write document for document 11705 of 12316
# Get embedding and write document for document 11706 of 12316
# Get embedding and write document for document 11707 of 12316
# Get embedding and write document for document 11708 of 12316
# Get embedding and write document for document 11709 of 12316
# Get embedding and write document for document 11710 of 12316
# Get embedding and write document for document 11711 of 12316
# Get embedding and write document for document 11712 of 12316
# Get embedding and write document for document 11713 of 12316
# Get embedding and write document for document 11714 of 12316
# Get embedding and write document for document 11715 of 12316
# Get embedding and write document for document 11716 of 12316
# Get embedding and write document for document 11717 of 12316
# Get embedding and write document for document 11718 of 12316
# Get embedding and write document for document 11719 of 12316
# Get embedding and write document for document 11720 of 12316
# Get embedding and write document for document 11721 of 12316
# Get embedding and write document for document 11722 of 12316
# Get embedding and write document for document 11723 of 12316
# Get embedding and write document for document 11724 of 12316
# Get embedding and write document for document 11725 of 12316
# Get embedding and write document for document 11726 of 12316
# Get embedding and write document for document 11727 of 12316
# Get embedding and write document for document 11728 of 12316
# Get embedding and write document for document 11729 of 12316
# Get embedding and write document for document 11730 of 12316
# Get embedding and write document for document 11731 of 12316
# Get embedding and write document for document 11732 of 12316
# Get embedding and write document for document 11733 of 12316
# Get embedding and write document for document 11734 of 12316
# Get embedding and write document for document 11735 of 12316
# Get embedding and write document for document 11736 of 12316
# Get embedding and write document for document 11737 of 12316
# Get embedding and write document for document 11738 of 12316
# Get embedding and write document for document 11739 of 12316
# Get embedding and write document for document 11740 of 12316
# Get embedding and write document for document 11741 of 12316
# Get embedding and write document for document 11742 of 12316
# Get embedding and write document for document 11743 of 12316
# Get embedding and write document for document 11744 of 12316
# Get embedding and write document for document 11745 of 12316
# Get embedding and write document for document 11746 of 12316
# Get embedding and write document for document 11747 of 12316
# Get embedding and write document for document 11748 of 12316
# Get embedding and write document for document 11749 of 12316
# Get embedding and write document for document 11750 of 12316
# Get embedding and write document for document 11751 of 12316
# Get embedding and write document for document 11752 of 12316
# Get embedding and write document for document 11753 of 12316
# Get embedding and write document for document 11754 of 12316
# Get embedding and write document for document 11755 of 12316
# Get embedding and write document for document 11756 of 12316
# Get embedding and write document for document 11757 of 12316
# Get embedding and write document for document 11758 of 12316
# Get embedding and write document for document 11759 of 12316
# Get embedding and write document for document 11760 of 12316
# Get embedding and write document for document 11761 of 12316
# Get embedding and write document for document 11762 of 12316
# Get embedding and write document for document 11763 of 12316
# Get embedding and write document for document 11764 of 12316
# Get embedding and write document for document 11765 of 12316
# Get embedding and write document for document 11766 of 12316
# Get embedding and write document for document 11767 of 12316
# Get embedding and write document for document 11768 of 12316
# Get embedding and write document for document 11769 of 12316
# Get embedding and write document for document 11770 of 12316
# Get embedding and write document for document 11771 of 12316
# Get embedding and write document for document 11772 of 12316
# Get embedding and write document for document 11773 of 12316
# Get embedding and write document for document 11774 of 12316
# Get embedding and write document for document 11775 of 12316
# Get embedding and write document for document 11776 of 12316
# Get embedding and write document for document 11777 of 12316
# Get embedding and write document for document 11778 of 12316
# Get embedding and write document for document 11779 of 12316
# Get embedding and write document for document 11780 of 12316
# Get embedding and write document for document 11781 of 12316
# Get embedding and write document for document 11782 of 12316
# Get embedding and write document for document 11783 of 12316
# Get embedding and write document for document 11784 of 12316
# Get embedding and write document for document 11785 of 12316
# Get embedding and write document for document 11786 of 12316
# Get embedding and write document for document 11787 of 12316
# Get embedding and write document for document 11788 of 12316
# Get embedding and write document for document 11789 of 12316
# Get embedding and write document for document 11790 of 12316
# Get embedding and write document for document 11791 of 12316
# Get embedding and write document for document 11792 of 12316
# Get embedding and write document for document 11793 of 12316
# Get embedding and write document for document 11794 of 12316
# Get embedding and write document for document 11795 of 12316
# Get embedding and write document for document 11796 of 12316
# Get embedding and write document for document 11797 of 12316
# Get embedding and write document for document 11798 of 12316
# Get embedding and write document for document 11799 of 12316
# Get embedding and write document for document 11800 of 12316
# Get embedding and write document for document 11801 of 12316
# Get embedding and write document for document 11802 of 12316

# %%
# write embeddings JSON file to separate directory 
os.chdir('/home/jupyter/data/embeddings_json_v2')

with open("embeddings.json", "w") as f:
    f.writelines(index_embeddings)

os.listdir()
# Out:
# ['embeddings.json']

# %% [markdown]
# # Create GCP Storage Bucket

# %%
# BUCKET_URI = f"gs://"  
# BUCKET_URI

# %%
# ! gsutil mb -l $REGION -p $PROJECT_ID $BUCKET_URI

# %% [markdown]
# # Copy Document Chunks and Embedding JSON  to GCP Bucket

# %%
# confirm in data folder
os.chdir('/home/jupyter/data/')
os.listdir()

# %% [markdown]
# # Copy Document Chunks

# %%
# # upload embedded docks to bucket
# !gsutil -m cp -r
# Out:
# Copying file://embedded_docs_v2/4954.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/45.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11396.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9435.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3466.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/117.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11734.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1686.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7619.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4793.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4079.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2903.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12285.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2107.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7543.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11344.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4509.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2055.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3230.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9080.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7748.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7375.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2772.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6681.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6593.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4809.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5139.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11695.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5687.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3790.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1614.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12027.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8035.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5455.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6805.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4366.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1650.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9921.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11544.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10476.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10166.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7997.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9952.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11338.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7560.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4168.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2989.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10964.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11025.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/742.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3548.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6181.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1057.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2020.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7840.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7217.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2830.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9456.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3281.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3265.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6549.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/874.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1069.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12205.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11449.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8688.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3484.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10039.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1629.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8274.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4902.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10269.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1328.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11697.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11711.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9636.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4667.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10332.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2683.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11918.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/901.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9765.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3803.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6105.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11731.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8588.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8393.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3758.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6379.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10150.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10636.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9416.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1405.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5517.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6880.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9023.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9241.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9796.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3992.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7122.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2781.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/633.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10541.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1649.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/708.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5930.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8326.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5523.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11061.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11321.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2682.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3866.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10782.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10231.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10743.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3224.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11658.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4070.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/65.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8394.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6912.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8576.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7328.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9814.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3076.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2761.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5253.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6166.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11803.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8275.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3914.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6776.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3399.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2216.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4740.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/311.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8522.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4738.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9325.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4558.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6758.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4196.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3929.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7655.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10100.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10363.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8269.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4619.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9852.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1662.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4978.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11571.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10336.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8693.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3248.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4957.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1488.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12119.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9266.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4779.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5509.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4242.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9594.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11649.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2773.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3450.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8435.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/689.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6611.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4003.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3453.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5714.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5661.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6774.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11473.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7966.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2259.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7601.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9328.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1895.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5686.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7740.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7714.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2398.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1342.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9334.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9403.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11835.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8623.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12057.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7726.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/597.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12155.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9143.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/286.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8488.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8030.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5552.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10805.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12043.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10665.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6142.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9171.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3588.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6377.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9059.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4582.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3125.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9324.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12306.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9530.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9487.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6158.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7492.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/534.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5072.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9210.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/126.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10831.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2950.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1857.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/72.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12040.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1011.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6945.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7947.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8150.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4050.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10282.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3756.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7690.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9203.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12138.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2610.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1856.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4148.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/235.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2545.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/94.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5786.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4030.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8489.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6562.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6830.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1276.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1667.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/776.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10741.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5584.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2245.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12114.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/434.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9253.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10417.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4270.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5278.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6041.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12082.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7994.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6740.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7325.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3811.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/84.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12162.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7244.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10930.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11328.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5373.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/936.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6501.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/362.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8758.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4883.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10981.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1736.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7559.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7268.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9848.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3813.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12218.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6131.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/810.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6509.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5912.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1954.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3892.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3434.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11774.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12203.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5684.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8487.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5655.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11133.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6124.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5787.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/432.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7645.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8179.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/422.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5361.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/303.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1385.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2836.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4706.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/964.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4722.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5371.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/591.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8441.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11868.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/87.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3393.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12252.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7858.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10454.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2923.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12313.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4213.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/491.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1672.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3096.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1712.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11915.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/80.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2357.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7121.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6394.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5243.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10597.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2163.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4255.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8478.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8640.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11457.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5795.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5518.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11268.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2440.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3900.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2704.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6342.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7786.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10161.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2302.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1347.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11876.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11048.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8032.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10467.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4493.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/975.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9878.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2762.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1656.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7265.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5559.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9320.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8506.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5002.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1140.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/741.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11211.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8365.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10928.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8613.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9971.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4827.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1943.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11726.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11087.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/923.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10032.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5392.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7546.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7510.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11278.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10507.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4939.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8879.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10104.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6061.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8217.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4167.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8658.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6683.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8268.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4519.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3053.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3007.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12224.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6535.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9893.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9518.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6282.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1958.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2092.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7192.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4878.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2454.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11815.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6722.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4643.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5096.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11917.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1159.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3153.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2685.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2862.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9866.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9115.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6773.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2832.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8463.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3418.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4250.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1038.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11999.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11251.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/737.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2840.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9555.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6076.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7573.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4958.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10561.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9119.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8596.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10725.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3728.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4690.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9704.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/724.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5568.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3619.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3147.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7039.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4358.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7662.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1529.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/480.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2757.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8015.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2787.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11928.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10047.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/989.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6995.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1197.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9856.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7890.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12307.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3723.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2250.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2207.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9400.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3109.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5342.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7057.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8911.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7738.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/979.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10126.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7609.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10483.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11255.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10787.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12033.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7688.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1042.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11897.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2559.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8711.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8044.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11358.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5291.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9175.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1510.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11616.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3143.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4373.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/873.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9481.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12291.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6288.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2553.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10752.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7789.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9850.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8707.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9798.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11189.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2638.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5616.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/271.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4041.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3474.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8775.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11531.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11310.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5889.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11171.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/460.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11226.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9643.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5484.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3367.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7012.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11023.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8857.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8916.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8523.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4451.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3968.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6887.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8372.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7449.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/36.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4607.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9398.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1409.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5873.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3207.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7347.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3751.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3586.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10389.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3850.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9198.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8628.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6888.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5557.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4951.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5520.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10564.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9012.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5048.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9664.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11836.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12021.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7494.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10982.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3069.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2114.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6626.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10377.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8578.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/277.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8083.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/926.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8090.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6442.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1611.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9901.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1320.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9031.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1623.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10816.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9379.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9743.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2552.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2807.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9228.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8591.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5910.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9498.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6071.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5854.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2449.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8114.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5543.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2707.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3549.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5647.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9795.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4637.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2337.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/298.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1750.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2342.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1486.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1378.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10354.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8662.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11404.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8132.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9154.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7843.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6027.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/722.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7022.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8843.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11639.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9587.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3134.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/246.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7656.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9709.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/68.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/290.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5805.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6547.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4409.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1033.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5569.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1172.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9504.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9252.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3253.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3946.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11280.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3516.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2385.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3454.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2891.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10937.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5634.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1640.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5210.txt [Content-Type=text/plain]...
# ...
# Copying file://embedded_docs_v2/448.txt [Content-Type=text/plain]... 00:00:02
# Copying file://embedded_docs_v2/4218.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/1928.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/10745.txt [Content-Type=text/plain]...0:00:02
# Copying file://embedded_docs_v2/2788.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7800.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/629.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/921.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8721.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/11971.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10455.txt [Content-Type=text/plain]...0:00:02
# Copying file://embedded_docs_v2/5145.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2165.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/7444.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/4903.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/104.txt [Content-Type=text/plain]... 00:00:02
# Copying file://embedded_docs_v2/10890.txt [Content-Type=text/plain]...0:00:02
# Copying file://embedded_docs_v2/3432.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/11384.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10273.txt [Content-Type=text/plain]...0:00:02
# Copying file://embedded_docs_v2/5733.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7924.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/1963.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/7475.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/11084.txt [Content-Type=text/plain]...0:00:02
# Copying file://embedded_docs_v2/582.txt [Content-Type=text/plain]... 00:00:02
# Copying file://embedded_docs_v2/7235.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/6122.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/5221.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/8354.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/6026.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/5665.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/10202.txt [Content-Type=text/plain]...0:00:02
# Copying file://embedded_docs_v2/3116.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/6367.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/2690.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/9720.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/9807.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/5029.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/2088.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/7814.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/12062.txt [Content-Type=text/plain]...0:00:02
# Copying file://embedded_docs_v2/10345.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2147.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/561.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7960.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6652.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3130.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/8670.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/6455.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6034.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3429.txt [Content-Type=text/plain]...00:00:02
# Copying file://embedded_docs_v2/665.txt [Content-Type=text/plain]... 00:00:01
# Copying file://embedded_docs_v2/4376.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/10010.txt [Content-Type=text/plain]...0:00:01
# Copying file://embedded_docs_v2/7979.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/6757.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3099.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11998.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8541.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/9024.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/9925.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7692.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/11992.txt [Content-Type=text/plain]...0:00:01
# Copying file://embedded_docs_v2/12277.txt [Content-Type=text/plain]...0:00:01
# Copying file://embedded_docs_v2/5775.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/10788.txt [Content-Type=text/plain]...0:00:01
# Copying file://embedded_docs_v2/9243.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/11476.txt [Content-Type=text/plain]...0:00:01
# Copying file://embedded_docs_v2/6366.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/7489.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4350.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/7798.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/3923.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/5981.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/4423.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/7864.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/9945.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/6743.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/2292.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/8675.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/9603.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9909.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5742.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/4318.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1885.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4760.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/6526.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/7863.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3361.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/6529.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/899.txt [Content-Type=text/plain]... 00:00:01
# Copying file://embedded_docs_v2/6991.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9461.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8674.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/12200.txt [Content-Type=text/plain]...0:00:01
# Copying file://embedded_docs_v2/9407.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/8415.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/5060.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/1177.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/9905.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/8877.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7544.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5896.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6084.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9534.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/3977.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5604.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/5961.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/4453.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/3507.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/4492.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/7887.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/10547.txt [Content-Type=text/plain]...0:00:01
# Copying file://embedded_docs_v2/9137.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/3193.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/1125.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/524.txt [Content-Type=text/plain]... 00:00:01
# Copying file://embedded_docs_v2/6524.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/9967.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/11758.txt [Content-Type=text/plain]...0:00:01
# Copying file://embedded_docs_v2/9666.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8714.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/5705.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/6101.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/1361.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/8830.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2171.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/6495.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9010.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/426.txt [Content-Type=text/plain]... 00:00:01
# Copying file://embedded_docs_v2/1258.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/8120.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/8864.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9038.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6531.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/8008.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6723.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/7780.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/1223.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5844.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/10771.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5906.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/12220.txt [Content-Type=text/plain]...0:00:01
# Copying file://embedded_docs_v2/5869.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/1555.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11349.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/383.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/731.txt [Content-Type=text/plain]... 00:00:01
# Copying file://embedded_docs_v2/7549.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/9352.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4428.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/11480.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/6235.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7821.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/9099.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/3640.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/5853.txt [Content-Type=text/plain]...00:00:01
# Copying file://embedded_docs_v2/12250.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1306.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/12094.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2229.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/10972.txt [Content-Type=text/plain]...0:00:00
# Copying file://embedded_docs_v2/6542.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4362.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1804.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4696.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/6164.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/9007.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/7679.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/3437.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/1734.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/8250.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/9829.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/7612.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7939.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/7976.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9988.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/9460.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/1922.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/9249.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/1573.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/8724.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/1589.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/9517.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/8145.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/3829.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/4705.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/3249.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/11247.txt [Content-Type=text/plain]...0:00:00
# Copying file://embedded_docs_v2/3911.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/6538.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/8174.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/6604.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/3050.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/5005.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/4587.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/7341.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/3489.txt [Content-Type=text/plain]...
# Copying file://embedded_docs_v2/2589.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/971.txt [Content-Type=text/plain]... 00:00:00
# Copying file://embedded_docs_v2/869.txt [Content-Type=text/plain]... 00:00:00
# Copying file://embedded_docs_v2/8510.txt [Content-Type=text/plain]...00:00:00
# Copying file://embedded_docs_v2/8061.txt [Content-Type=text/plain]...00:00:00
# - [12.3k/12.3k files][223.5 MiB/223.5 MiB] 100% Done  54.1 KiB/s ETA 00:00:00
# Operation completed over 12.3k objects/223.5 MiB.

# %%
print('upload finished')
# Out:
# upload finished

# %% [markdown]
# ## Copy Embeddings JSON File

# %%
# !gsutil cp embeddings.json gs://
